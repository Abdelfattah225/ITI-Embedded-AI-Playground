# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_absolute_error, root_mean_squared_error,mean_squared_error,r2_score

# %%
np.random.seed(42)
X=np.random.rand(100,1)*10
X
# Out:
# array([[3.74540119],
#        [9.50714306],
#        [7.31993942],
#        [5.98658484],
#        [1.5601864 ],
#        [1.5599452 ],
#        [0.58083612],
#        [8.66176146],
#        [6.01115012],
#        [7.08072578],
#        [0.20584494],
#        [9.69909852],
#        [8.32442641],
#        [2.12339111],
#        [1.81824967],
#        [1.8340451 ],
#        [3.04242243],
#        [5.24756432],
#        [4.31945019],
#        [2.9122914 ],
#        [6.11852895],
#        [1.39493861],
#        [2.92144649],
#        [3.66361843],
#        [4.56069984],
#        [7.85175961],
#        [1.99673782],
#        [5.14234438],
#        [5.92414569],
#        [0.46450413],
#        [6.07544852],
#        [1.70524124],
#        [0.65051593],
#        [9.48885537],
#        [9.65632033],
#        [8.08397348],
#        [3.04613769],
#        [0.97672114],
#        [6.84233027],
#        [4.40152494],
#        [1.22038235],
#        [4.9517691 ],
#        [0.34388521],
#        [9.09320402],
#        [2.58779982],
#        [6.62522284],
#        [3.11711076],
#        [5.20068021],
#        [5.46710279],
#        [1.84854456],
#        [9.69584628],
#        [7.75132823],
#        [9.39498942],
#        [8.9482735 ],
#        [5.97899979],
#        [9.21874235],
#        [0.88492502],
#        [1.95982862],
#        [0.45227289],
#        [3.25330331],
#        [3.8867729 ],
#        [2.71349032],
#        [8.28737509],
#        [3.56753327],
#        [2.8093451 ],
#        [5.42696083],
#        [1.40924225],
#        [8.02196981],
#        [0.74550644],
#        [9.86886937],
#        [7.72244769],
#        [1.98715682],
#        [0.05522117],
#        [8.15461428],
#        [7.06857344],
#        [7.29007168],
#        [7.71270347],
#        [0.74044652],
#        [3.58465729],
#        [1.1586906 ],
#        [8.63103426],
#        [6.23298127],
#        [3.30898025],
#        [0.6355835 ],
#        [3.10982322],
#        [3.25183322],
#        [7.29606178],
#        [6.37557471],
#        [8.87212743],
#        [4.72214925],
#        [1.19594246],
#        [7.13244787],
#        [7.60785049],
#        [5.61277198],
#        [7.7096718 ],
#        [4.93795596],
#        [5.22732829],
#        [4.27541018],
#        [0.25419127],
#        [1.07891427]])

# %%
y_act=2.5*X**2+0.5*X+np.random.randn(100,1)

# %%
y_act
# Out:
# array([[ 3.70298228e+01],
#        [ 2.30418987e+02],
#        [ 1.37705513e+02],
#        [ 9.06037187e+01],
#        [ 6.64587536e+00],
#        [ 7.22065777e+00],
#        [ 2.61173861e+00],
#        [ 1.91377889e+02],
#        [ 9.25318958e+01],
#        [ 1.28380300e+02],
#        [ 1.12425494e+00],
#        [ 2.40359581e+02],
#        [ 1.76872641e+02],
#        [ 1.28469375e+01],
#        [ 9.27128206e+00],
#        [ 1.02949711e+01],
#        [ 2.39599937e+01],
#        [ 7.11384481e+01],
#        [ 4.84117417e+01],
#        [ 2.11962338e+01],
#        [ 9.69463759e+01],
#        [ 5.82315887e+00],
#        [ 2.28029606e+01],
#        [ 3.51524721e+01],
#        [ 5.28649368e+01],
#        [ 1.57630557e+02],
#        [ 1.06230592e+01],
#        [ 6.78781593e+01],
#        [ 9.05395425e+01],
#        [ 1.17571313e+00],
#        [ 9.72015969e+01],
#        [ 8.29681762e+00],
#        [ 1.64073579e+00],
#        [ 2.29765922e+02],
#        [ 2.36020695e+02],
#        [ 1.67392041e+02],
#        [ 2.47806861e+01],
#        [ 5.33656315e+00],
#        [ 1.20272513e+02],
#        [ 5.09358642e+01],
#        [ 4.29881210e+00],
#        [ 6.26072496e+01],
#        [ 1.61040802e+00],
#        [ 2.12014433e+02],
#        [ 1.88267016e+01],
#        [ 1.12137168e+02],
#        [ 2.72522984e+01],
#        [ 6.88161757e+01],
#        [ 7.80434409e+01],
#        [ 1.16575203e+01],
#        [ 2.38880974e+02],
#        [ 1.53517090e+02],
#        [ 2.25461711e+02],
#        [ 2.04149658e+02],
#        [ 9.08099326e+01],
#        [ 2.17140960e+02],
#        [ 1.33788953e+00],
#        [ 1.10558273e+01],
#        [-1.81910874e-01],
#        [ 2.96365421e+01],
#        [ 3.89276420e+01],
#        [ 1.94422579e+01],
#        [ 1.76658670e+02],
#        [ 3.23711363e+01],
#        [ 2.13631822e+01],
#        [ 7.76503828e+01],
#        [ 4.06204719e+00],
#        [ 1.65075618e+02],
#        [ 2.02208563e+00],
#        [ 2.49202714e+02],
#        [ 1.51714769e+02],
#        [ 9.54510232e+00],
#        [ 5.57175596e-01],
#        [ 1.70618627e+02],
#        [ 1.28696606e+02],
#        [ 1.36854347e+02],
#        [ 1.51890814e+02],
#        [ 1.97312957e+00],
#        [ 3.42098208e+01],
#        [ 3.22140362e+00],
#        [ 1.92418173e+02],
#        [ 1.00715462e+02],
#        [ 2.78365623e+01],
#        [ 1.98426133e+00],
#        [ 2.47577310e+01],
#        [ 2.88490494e+01],
#        [ 1.37887920e+02],
#        [ 1.03986987e+02],
#        [ 2.02186052e+02],
#        [ 5.85205894e+01],
#        [ 4.99572731e+00],
#        [ 1.32642549e+02],
#        [ 1.48257010e+02],
#        [ 8.08106730e+01],
#        [ 1.51562920e+02],
#        [ 6.26116904e+01],
#        [ 7.08489652e+01],
#        [ 4.81766877e+01],
#        [ 5.65319434e-01],
#        [ 4.27678039e+00]])

# %%
plt.scatter(X,y_act)
plt.xlabel("X")
plt.ylabel("y_act")
plt.title("Scatter plot of X vs y_act")
plt.show()

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y_act,test_size=0.2,random_state=42)

# %%
poly_features=PolynomialFeatures(degree=20)
X_train_poly=poly_features.fit_transform(X_train)
X_test_poly=poly_features.transform(X_test)

# %%
model=LinearRegression()
model.fit(X_train_poly,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred=model.predict(X_train_poly)
y_test_pred=model.predict(X_test_poly)

# %%
print(f"Train Root Mean Squared Error: {root_mean_squared_error(y_train,y_train_pred)}")
print(f"Test Root Mean Squared Error: {root_mean_squared_error(y_test,y_test_pred)}")
# Out:
# Train Root Mean Squared Error: 6.748475678739036
# Test Root Mean Squared Error: 6.997107720323603

# %%
print(f"Train Absolute Error: {mean_absolute_error(y_train,y_train_pred)}")
print(f"Test Absolute Error: {mean_absolute_error(y_test,y_test_pred)}")
# Out:
# Train Absolute Error: 5.316857278956188
# Test Absolute Error: 6.356959074805551

# %%
print(f"Train MSE: {mean_squared_error(y_train,y_train_pred)}")
print(f"Test MSE: {mean_squared_error(y_test,y_test_pred)}")
# Out:
# Train MSE: 45.54192398653228
# Test MSE: 48.95951644981217

# %%
print(f"Train R2: {r2_score(y_train,y_train_pred)}")
print(f"Test R2: {r2_score(y_test,y_test_pred)}")
# Out:
# Train R2: 0.9918665539232759
# Test R2: 0.9921388170471244

# %% [markdown]
# # SESSION 4

# %%
Lasso_model=Lasso(alpha=0.1) # regularization parameter alpha
Lasso_model.fit(X_train_poly,y_train)


y_train_pred=Lasso_model.predict(X_train_poly)
y_test_pred=Lasso_model.predict(X_test_poly)
# Out:
# /home/abdo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.557e+01, tolerance: 4.479e+01
#   model = cd_fast.enet_coordinate_descent(

# %%
print(f"Train Root Mean Squared Error: {root_mean_squared_error(y_train,y_train_pred)}")
print(f"Test Root Mean Squared Error: {root_mean_squared_error(y_test,y_test_pred)}")
# Out:
# Train Root Mean Squared Error: 0.894210897515906
# Test Root Mean Squared Error: 0.8787698255020582

# %%
print(f"Train Absolute Error: {mean_absolute_error(y_train,y_train_pred)}")
print(f"Test Absolute Error: {mean_absolute_error(y_test,y_test_pred)}")
# Out:
# Train Absolute Error: 0.7151377862640904
# Test Absolute Error: 0.6656489479973459

# %%
print(f"Train R2: {r2_score(y_train,y_train_pred)}")
print(f"Test R2: {r2_score(y_test,y_test_pred)}")
# Out:
# Train R2: 0.9998571950919156
# Test R2: 0.9998760058899206

# %% [markdown]
# # L2

# %%
Ridge_model=Ridge(alpha=0.1) # regularization parameter alpha
Ridge_model.fit(X_train_poly,y_train)

y_train_pred=Ridge_model.predict(X_train_poly)
y_test_pred=Ridge_model.predict(X_test_poly)

# %%
print(f"Train Root Mean Squared Error: {root_mean_squared_error(y_train,y_train_pred)}")
print(f"Test Root Mean Squared Error: {root_mean_squared_error(y_test,y_test_pred)}")
# Out:
# Train Root Mean Squared Error: 3.893366682837268
# Test Root Mean Squared Error: 2.7478444781112494

# %%
print(f"Train Absolute Error: {mean_absolute_error(y_train,y_train_pred)}")
print(f"Test Absolute Error: {mean_absolute_error(y_test,y_test_pred)}")
# Out:
# Train Absolute Error: 2.2402146233953393
# Test Absolute Error: 1.9997661926147998

# %%
print(f"Train R2: {r2_score(y_train,y_train_pred)}")
print(f"Test R2: {r2_score(y_test,y_test_pred)}")
# Out:
# Train R2: 0.9972928405644825
# Test R2: 0.9987876302775256

# %%
print(f"Train MSE: {mean_squared_error(y_train,y_train_pred)}")
print(f"Test MSE: {mean_squared_error(y_test,y_test_pred)}")
# Out:
# Train MSE: 15.15830412702727
# Test MSE: 7.550649275886485
