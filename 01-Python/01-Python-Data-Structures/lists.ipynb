# %%
x=2
u=22

name = 'Abdelfattah'
age = 23
is_student = False
score  = 5.255558
print("name:", name , "is student : ", is_student , "age: ", age , "score : ", score)
print(f"name: {name}\nis student: {is_student}\nage: {age}\nscore: {score}")
# Out:
# name: Abdelfattah is student :  False age:  23 score :  5.255558
# name: Abdelfattah
# is student: False
# age: 23
# score: 5.255558

# %%
mylist = [1,False,4.25,[True,14]]
fruits = ["apple", "banana", "cherry"]

fruits[1] = "blueberry"
fruits.append("date")
fruits.insert(1,25)

fruits.remove("apple")
fruits.pop(1)

fruits.reverse()
fruits.append("date")
x = fruits.count("date")
fruits.clear()

fruits
# Out:
# []

# %%
shopping = [ "milk ", "eggs" , "bread"]
shopping.append("butter")
print(f"i need to buy {len(shopping)} items")
# Out:
# i need to buy 4 items
