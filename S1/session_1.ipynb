# %% [markdown]
# Hello

# %%
x=4
y=5
print(x)
y
name = 'abdelfattah'
age = 29
is_student=True
score = 65.287897979

print(f"name: {name}\nAge: {age}\nIs_student{is_student}\nscore {score:.3f}  ")

fruits=["apple",2.5,["banana",1]]

print(fruits[::] )

fruits.append(4)
# Out:
# 4
# name: abdelfattah
# Age: 29
# Is_studentTrue
# score 65.288
# ['apple', 2.5, ['banana', 1]]

# %%
my_list = ["Apple", 2,4,2.3,True,[1,2,3]]
print(my_list[1])

my_list.append("AI")

print(my_list)
my_list

my_list.insert(2,"False")

my_list

my_list_2 = [5,7,8,9]

my_list.append(my_list_2)

my_list
# Out:
# 2
# ['Apple', 2, 4, 2.3, True, [1, 2, 3], 'AI']
# ['Apple', 2, 'False', 4, 2.3, True, [1, 2, 3], 'AI', [5, 7, 8, 9]]

# %%
my_dic={
   "Name" : "Abdo",
   "Jpb" : "Engineer",
   "Courses": ["AI","CV"]
}


my_dic["Jpb"]


my_dic['Age'] = 26

my_dic
# Out:
# {'Name': 'Abdo', 'Jpb': 'Engineer', 'Courses': ['AI', 'CV'], 'Age': 26}

# %%
my_dic["Age"] = 18
my_dic.pop("Name")
my_dic
# Out:
# {'Jpb': 'Engineer', 'Courses': ['AI', 'CV'], 'Age': 18}

# %%
num = 8 
if num>0:
    print("number is greater than zero")

if "apple" in fruits:
    print("File exist")
# Out:
# number is greater than zero
# File exist

# %%
fruits=["apple",2.5,["banana",1]]
for i in fruits:
    if i == "apple":
        print("i hate apples")
        break

    print(f"I like {i}")
# Out:
# i hate apples

# %%
for i in range(5,0,-1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1
