# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2  # Fixed spelling
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %%
# STEP 1: Generate Data
# Create binary classification data with 500 features
# n_samples=2000, n_features=500, n_classes=2
# YOUR CODE HERE
x,y=make_classification(n_samples=2000, n_features=500,n_informative=100, n_classes=2)

# STEP 2: Split Data
# 80% train, 20% test
# YOUR CODE HERE
x_train, x_test , y_train, y_test = train_test_split(x,y,test_size=.2,random_state=42)

# %%
# STEP 3: Build Model
model=Sequential()
# input layer
model.add(
    Dense(256,activation='relu',kernel_regularizer=l2(0.01),input_shape=(500,))
)

# hidden layers
model.add(
    Dense(128,activation='relu',kernel_regularizer=l2(0.01))
)
model.add(Dropout(0.5))
model.add(
    Dense(64,activation='relu',kernel_regularizer=l2(0.01))
)

# out layer
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# compile

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
# early stop
early_stop = EarlyStopping(monitor='val_loss', patience=5)

# %%
# train
model.fit(x_train, y_train, epochs=50, batch_size=50, validation_split=0.2,callbacks=[early_stop])
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.5796 - loss: 6.7537 - val_accuracy: 0.7250 - val_loss: 5.6863
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7124 - loss: 5.4837 - val_accuracy: 0.8062 - val_loss: 4.7450
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8496 - loss: 4.4572 - val_accuracy: 0.8313 - val_loss: 3.9492
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9266 - loss: 3.6379 - val_accuracy: 0.8594 - val_loss: 3.3214
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9534 - loss: 3.0070 - val_accuracy: 0.8594 - val_loss: 2.8416
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9650 - loss: 2.5272 - val_accuracy: 0.8531 - val_loss: 2.4930
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9745 - loss: 2.1476 - val_accuracy: 0.8687 - val_loss: 2.1916
# Epoch 8/50
# ...

# %%
model.evaluate(x_test,y_test)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9032 - loss: 0.4552
# [0.4868265986442566, 0.8999999761581421]
